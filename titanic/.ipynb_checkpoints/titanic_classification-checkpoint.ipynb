# %%
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
titanic =pd.read_csv('final_dataset.csv')
dataset=titanic.copy()
X=np.asarray(dataset.drop('Survived',1))
y=np.asarray(dataset['Survived'])

# %%
#splliting data for training and testing
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state = 0)

# %%
#normalizing the data by keeping them in standard scale
sc= StandardScaler()
X_train_normalized = sc.fit_transform(X_train)
X_test_normalized = sc.transform(X_test)

# %%
#defining the neural network architechture

numDims = X_train_normalized.shape[1] #gets the number of features of the data
#fully conected architecture hence use dense
dnnModel = tf.keras.Sequential([
    layers.Dense(15,activation='elu',input_shape =(numDims,)),
    
    layers.Dropout(0.3),
    layers.Dense(19,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.21),
    layers.Dense(120,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(160,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(20,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.1),
    layers.BatchNormalization(),
    layers.Dense(2) #binary classifiacation problem hence only 2 neurons in output layer
    
])
optimizer = tf.keras.optimizers.RMSprop(0.01)
dnnModel.compile(optimizer=optimizer,loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True),metrics = ['accuracy'])

# %%
dnnModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 15)                150
# _________________________________________________________________
# dropout (Dropout)            (None, 15)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 19)                76
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               2400
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120)               480
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 160)               19360
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 160)               640
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 160)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                3220
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 20)                80
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20)                0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 20)                80
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 42
# =================================================================
# Total params: 26,832
# Trainable params: 26,154
# Non-trainable params: 678
# _________________________________________________________________

# %%
dnnModel.fit(X_train_normalized , y_train, epochs =100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6579 - accuracy: 0.6671
# Epoch 2/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5239 - accuracy: 0.7317
# Epoch 3/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5190 - accuracy: 0.7542
# Epoch 4/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5068 - accuracy: 0.7753
# Epoch 5/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4845 - accuracy: 0.7823
# Epoch 6/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.8006
# Epoch 7/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4556 - accuracy: 0.8202
# Epoch 8/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4830 - accuracy: 0.8034
# Epoch 9/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4711 - accuracy: 0.8020
# Epoch 10/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4832 - accuracy: 0.7949
# Epoch 11/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.7992
# Epoch 12/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4696 - accuracy: 0.8090
# Epoch 13/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4841 - accuracy: 0.7823
# Epoch 14/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.8048
# Epoch 15/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4710 - accuracy: 0.7963
# Epoch 16/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.8188
# Epoch 17/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4575 - accuracy: 0.8160
# Epoch 18/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4620 - accuracy: 0.8006
# Epoch 19/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4641 - accuracy: 0.8160
# Epoch 20/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4507 - accuracy: 0.8272
# Epoch 21/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.8062
# Epoch 22/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4470 - accuracy: 0.8188
# Epoch 23/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.8244
# Epoch 24/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4577 - accuracy: 0.8258
# Epoch 25/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4593 - accuracy: 0.8188
# Epoch 26/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.8118
# Epoch 27/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.8146
# Epoch 28/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.8062
# Epoch 29/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.8272
# Epoch 30/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.8146
# Epoch 31/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4169 - accuracy: 0.8441
# Epoch 32/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4462 - accuracy: 0.8216
# Epoch 33/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4405 - accuracy: 0.8174
# Epoch 34/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4533 - accuracy: 0.8160
# Epoch 35/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4110 - accuracy: 0.8343
# Epoch 36/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4294 - accuracy: 0.8174
# Epoch 37/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.8216
# Epoch 38/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.8062
# Epoch 39/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4317 - accuracy: 0.8202
# Epoch 40/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4451 - accuracy: 0.8230
# Epoch 41/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4311 - accuracy: 0.8258
# Epoch 42/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4386 - accuracy: 0.8230
# Epoch 43/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4431 - accuracy: 0.8244
# Epoch 44/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4533 - accuracy: 0.8090
# Epoch 45/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.8272
# Epoch 46/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4398 - accuracy: 0.8160
# Epoch 47/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4328 - accuracy: 0.8230
# Epoch 48/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.8244
# Epoch 49/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.8244
# Epoch 50/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4356 - accuracy: 0.8244
# Epoch 51/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8301
# Epoch 52/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.8160
# Epoch 53/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4172 - accuracy: 0.8287
# Epoch 54/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.8216
# Epoch 55/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4267 - accuracy: 0.8301
# Epoch 56/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.8315
# Epoch 57/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4524 - accuracy: 0.8272
# Epoch 58/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4285 - accuracy: 0.8287
# Epoch 59/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4348 - accuracy: 0.8188
# Epoch 60/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.8174
# Epoch 61/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4411 - accuracy: 0.8132
# Epoch 62/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4412 - accuracy: 0.8216
# Epoch 63/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4285 - accuracy: 0.8329
# Epoch 64/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.8301
# Epoch 65/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.8385
# Epoch 66/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4422 - accuracy: 0.8230
# Epoch 67/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4274 - accuracy: 0.8385
# Epoch 68/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4408 - accuracy: 0.8216
# Epoch 69/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4327 - accuracy: 0.8244
# Epoch 70/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.8301
# Epoch 71/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.8357
# Epoch 72/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4322 - accuracy: 0.8244
# Epoch 73/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4191 - accuracy: 0.8357
# Epoch 74/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4356 - accuracy: 0.8216
# Epoch 75/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4314 - accuracy: 0.8230
# Epoch 76/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.8357
# Epoch 77/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4357 - accuracy: 0.8244
# Epoch 78/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.8329
# Epoch 79/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4164 - accuracy: 0.8301
# Epoch 80/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4171 - accuracy: 0.8272
# Epoch 81/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4140 - accuracy: 0.8329
# Epoch 82/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.8216
# Epoch 83/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.8146
# Epoch 84/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4260 - accuracy: 0.8258
# Epoch 85/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4263 - accuracy: 0.8202
# Epoch 86/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4071 - accuracy: 0.8287
# Epoch 87/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4337 - accuracy: 0.8174
# Epoch 88/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.8202
# Epoch 89/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4491 - accuracy: 0.8202
# Epoch 90/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4354 - accuracy: 0.8287
# Epoch 91/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4237 - accuracy: 0.8301
# Epoch 92/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4215 - accuracy: 0.8301
# Epoch 93/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4314 - accuracy: 0.8244
# Epoch 94/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8385
# Epoch 95/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4364 - accuracy: 0.8188
# Epoch 96/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4217 - accuracy: 0.8272
# Epoch 97/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4124 - accuracy: 0.8357
# Epoch 98/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4280 - accuracy: 0.8202
# Epoch 99/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8244
# Epoch 100/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4294 - accuracy: 0.8272

# %%
#checking test accuracy
test_loss,test_acc = dnnModel.evaluate(X_test_normalized , y_test, verbose=2)
print('\nTest accuracy :', test_acc)
# Out:
# 6/6 - 0s - loss: 0.4307 - accuracy: 0.8212
#
# Test accuracy : 0.8212290406227112

# %%
y_pred = dnnModel.predict_classes(X_test)

# %%
idx = np.random.randint(1,len(y_test))
print('Index = ',idx,' Predicted :: ',y_pred[idx],'actual : ',y_test[idx])
# Out:
# Index =  72  Predicted ::  0 actual :  0

# %%
titanic.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0         0       3    1  22.0      1      0   7.2500           0           0
# 1         1       1    0  38.0      1      0  71.2833           1           0
# 2         1       3    0  26.0      0      0   7.9250           0           0
# 3         1       1    0  35.0      1      0  53.1000           0           0
# 4         0       3    1  35.0      0      0   8.0500           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
