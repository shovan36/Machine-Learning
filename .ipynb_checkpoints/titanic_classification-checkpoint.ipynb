# %%
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
titanic =pd.read_csv('final_dataset.csv')
dataset=titanic.copy()
X=np.asarray(dataset.drop('Survived',1))
y=np.asarray(dataset['Survived'])

# %%
#splliting data for training and testing
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state = 0)

# %%
#normalizing the data by keeping them in standard scale
sc= StandardScaler()
X_train_normalized = sc.fit_transform(X_train)
X_test_normalized = sc.transform(X_test)

# %%
#defining the neural network architechture

numDims = X_train_normalized.shape[1] #gets the number of features of the data
#fully conected architecture hence use dense
dnnModel = tf.keras.Sequential([
    layers.Dense(15,activation='elu',input_shape =(numDims,)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(19,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.21),
    layers.Dense(120,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(160,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(20,activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.1),
    layers.BatchNormalization(),
    layers.Dense(2) #binary classifiacation problem hence only 2 neurons in output layer
    
])
optimizer = tf.keras.optimizers.RMSprop(0.01)
dnnModel.compile(optimizer=optimizer,loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True),metrics = ['accuracy'])

# %%
dnnModel.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_148 (Dense)            (None, 15)                150
# _________________________________________________________________
# batch_normalization_146 (Bat (None, 15)                60
# _________________________________________________________________
# dropout_122 (Dropout)        (None, 15)                0
# _________________________________________________________________
# dense_149 (Dense)            (None, 19)                304
# _________________________________________________________________
# batch_normalization_147 (Bat (None, 19)                76
# _________________________________________________________________
# dropout_123 (Dropout)        (None, 19)                0
# _________________________________________________________________
# dense_150 (Dense)            (None, 120)               2400
# _________________________________________________________________
# batch_normalization_148 (Bat (None, 120)               480
# _________________________________________________________________
# dropout_124 (Dropout)        (None, 120)               0
# _________________________________________________________________
# dense_151 (Dense)            (None, 160)               19360
# _________________________________________________________________
# batch_normalization_149 (Bat (None, 160)               640
# _________________________________________________________________
# dropout_125 (Dropout)        (None, 160)               0
# _________________________________________________________________
# dense_152 (Dense)            (None, 20)                3220
# _________________________________________________________________
# batch_normalization_150 (Bat (None, 20)                80
# _________________________________________________________________
# dropout_126 (Dropout)        (None, 20)                0
# _________________________________________________________________
# batch_normalization_151 (Bat (None, 20)                80
# _________________________________________________________________
# dense_153 (Dense)            (None, 2)                 42
# =================================================================
# Total params: 26,892
# Trainable params: 26,184
# Non-trainable params: 708
# _________________________________________________________________

# %%
dnnModel.fit(X_train_normalized , y_train, epochs =100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6973 - accuracy: 0.6685
# Epoch 2/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5727 - accuracy: 0.7317
# Epoch 3/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.5120 - accuracy: 0.7781
# Epoch 4/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4961 - accuracy: 0.7893
# Epoch 5/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5063 - accuracy: 0.7865
# Epoch 6/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4941 - accuracy: 0.7781
# Epoch 7/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4947 - accuracy: 0.7837
# Epoch 8/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4988 - accuracy: 0.7697
# Epoch 9/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4924 - accuracy: 0.7921
# Epoch 10/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4920 - accuracy: 0.8006
# Epoch 11/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4702 - accuracy: 0.8048
# Epoch 12/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4670 - accuracy: 0.8118
# Epoch 13/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4627 - accuracy: 0.8048
# Epoch 14/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4731 - accuracy: 0.8006
# Epoch 15/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4521 - accuracy: 0.8132
# Epoch 16/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4683 - accuracy: 0.8020
# Epoch 17/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4804 - accuracy: 0.8034
# Epoch 18/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.8034
# Epoch 19/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4544 - accuracy: 0.8146
# Epoch 20/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4508 - accuracy: 0.8272
# Epoch 21/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4360 - accuracy: 0.8329
# Epoch 22/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4664 - accuracy: 0.8062
# Epoch 23/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4491 - accuracy: 0.8188
# Epoch 24/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4676 - accuracy: 0.7978
# Epoch 25/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4605 - accuracy: 0.8118
# Epoch 26/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4478 - accuracy: 0.8230
# Epoch 27/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4504 - accuracy: 0.8132
# Epoch 28/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.8244
# Epoch 29/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4448 - accuracy: 0.8244
# Epoch 30/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4522 - accuracy: 0.8146
# Epoch 31/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4473 - accuracy: 0.8188
# Epoch 32/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.8090
# Epoch 33/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.8301
# Epoch 34/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4619 - accuracy: 0.8174
# Epoch 35/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.8146
# Epoch 36/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4453 - accuracy: 0.8244
# Epoch 37/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4398 - accuracy: 0.8216
# Epoch 38/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4416 - accuracy: 0.8287
# Epoch 39/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.8132
# Epoch 40/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4504 - accuracy: 0.8160
# Epoch 41/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4245 - accuracy: 0.8216
# Epoch 42/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4447 - accuracy: 0.8230
# Epoch 43/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4486 - accuracy: 0.8160
# Epoch 44/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.8188
# Epoch 45/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4285 - accuracy: 0.8160
# Epoch 46/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4510 - accuracy: 0.8188
# Epoch 47/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.8216
# Epoch 48/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.8062
# Epoch 49/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4298 - accuracy: 0.8244
# Epoch 50/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4562 - accuracy: 0.8174
# Epoch 51/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4445 - accuracy: 0.8174
# Epoch 52/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4234 - accuracy: 0.8329
# Epoch 53/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4173 - accuracy: 0.8385
# Epoch 54/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4367 - accuracy: 0.8188
# Epoch 55/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4459 - accuracy: 0.8272
# Epoch 56/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.8146
# Epoch 57/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4303 - accuracy: 0.8287
# Epoch 58/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.8188
# Epoch 59/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4458 - accuracy: 0.8160
# Epoch 60/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.8329
# Epoch 61/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4433 - accuracy: 0.8287
# Epoch 62/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4235 - accuracy: 0.8427
# Epoch 63/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.8272
# Epoch 64/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4458 - accuracy: 0.8188
# Epoch 65/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4470 - accuracy: 0.8104
# Epoch 66/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.8244
# Epoch 67/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4500 - accuracy: 0.8118
# Epoch 68/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4519 - accuracy: 0.8272
# Epoch 69/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.8230
# Epoch 70/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4256 - accuracy: 0.8301
# Epoch 71/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.8287
# Epoch 72/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.8272
# Epoch 73/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4488 - accuracy: 0.8132
# Epoch 74/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.8329
# Epoch 75/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4271 - accuracy: 0.8244
# Epoch 76/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4485 - accuracy: 0.8329
# Epoch 77/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4339 - accuracy: 0.8301
# Epoch 78/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.8287
# Epoch 79/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.8329
# Epoch 80/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.8258
# Epoch 81/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4435 - accuracy: 0.8202
# Epoch 82/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.8216
# Epoch 83/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4074 - accuracy: 0.8483
# Epoch 84/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4476 - accuracy: 0.8174
# Epoch 85/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.8272
# Epoch 86/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4236 - accuracy: 0.8371
# Epoch 87/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4241 - accuracy: 0.8230
# Epoch 88/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.8357
# Epoch 89/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.8258
# Epoch 90/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4588 - accuracy: 0.8188
# Epoch 91/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4256 - accuracy: 0.8329
# Epoch 92/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4277 - accuracy: 0.8202
# Epoch 93/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.8258
# Epoch 94/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.8287
# Epoch 95/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.8343
# Epoch 96/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.8188
# Epoch 97/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4267 - accuracy: 0.8357
# Epoch 98/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4257 - accuracy: 0.8272
# Epoch 99/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4230 - accuracy: 0.8343
# Epoch 100/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4356 - accuracy: 0.8258

# %%
#checking test accuracy
test_loss,test_acc = dnnModel.evaluate(X_test_normalized , y_test, verbose=2)
print('\nTest accuracy :', test_acc)
# Out:
# 6/6 - 0s - loss: 0.4146 - accuracy: 0.8212
#
# Test accuracy : 0.8212290406227112

# %%
y_pred = dnnModel.predict_classes(X_test)

# %%
idx = np.random.randint(1,len(y_test))
print('Index = ',idx,' Predicted :: ',y_pred[idx],'actual : ',y_test[idx])
# Out:
# Index =  54  Predicted ::  1 actual :  1
