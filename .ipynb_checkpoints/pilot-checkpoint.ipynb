# %%
print(round(4.5656,3))
# Out:
# 4.566

# %%
c=complex('5+2j')
print(type(c))
print(abs(c))
# Out:
# <class 'complex'>
# 5.385164807134504

# %%
divmod(9,2)
# Out:
# (4, 1)

# %%
print(isinstance(1.8,(float,int)))
# Out:
# True

# %%
print(pow(7,3,2
         ))

# %%
a=input(int("enter a number"))
print(a)
# Out:
# enter a numbery
# y

# %%
a=[1,2,3,4,7,6,7,8,9]
b=[34,3]
z=[a,b]
print (z[0])
# Out:
# [1, 2, 3, 4, 7, 6, 7, 8, 9]

# %%
print(a[:len(a):3])
# Out:
# [1, 4, 7]

# %%
print(a+b)
# Out:
# [1, 2, 3, 4, 7, 6, 7, 8, 9, 34, 3]
