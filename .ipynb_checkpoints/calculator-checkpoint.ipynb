# %%
x=input("enter a number")
ch=input("enter the operation")
y=input("enter second number")
x= float(x)
y= float(y)
if ch =='+':
    print(x+y)
elif ch=='-':
    print(f"{x}+ {y}={x+y}")
elif ch=='-':
          print(f"{x}-{y}={x-y}")
else:
    print("error")
# Out:
# enter a number8
# enter the operation+
# enter second number9
# 17.0
