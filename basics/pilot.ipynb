# %%
print(round(4.5656,3))
# Out:
# 4.566

# %%
c=complex('5+2j')
print(type(c))
print(abs(c))
# Out:
# <class 'complex'>
# 5.385164807134504

# %%
divmod(9,2)
# Out:
# (4, 1)

# %%
print(isinstance(1.8,(float,int)))
# Out:
# True

# %%
print(pow(7,3,2
         ))

# %%
a=input(int("enter a number"))
print(a)
# Out:
# enter a numbery
# y

# %%
a=[1,2,3,4,7,6,7,8,9]
b=[34,3]
z=[a,b]
print (z[0])
# Out:
# [1, 2, 3, 4, 7, 6, 7, 8, 9]

# %%
print(a[:len(a):3])
# Out:
# [1, 4, 7]

# %%
print(a+b)
a.append(69)
# Out:
# [1, 2, 3, 4, 7, 6, 7, 8, 9, 34, 3]

# %%
print(a
)
# Out:
# [1, 2, 3, 4, 7, 6, 7, 8, 9, 69]

# %%
a.append(b)
print(a)
# Out:
# [1, 2, 3, 4, 7, 6, 7, 8, 9, 69, 34, 3, [34, 3]]

# %%
a.remove(max(a))
print(a)
a.pop(min(a))
# Out:
# [1, 2, 4, 6, 7, 8]
# 2

# %%
c=a.copy()
print (c)
# Out:
# [1, 4, 6, 7, 8]

# %%
hi=(2,3,4,'tr')
print(hi)
# Out:
# (2, 3, 4, 'tr')

# %%
set={1,1,23,4,3,2}
print(set)
otherset={2,1,12,3,4,3,1}
set.union(otherset)
set.intersection(otherset)
set1={1,2}
set1.issubset(set)
# Out:
# {1, 2, 3, 4, 23}
# True

# %%
dict={'1':34,'name':'shovan','list':[3,5,4,'w']}
print(dict)
dict['list'][:2]
# Out:
# {'1': 34, 'name': 'shovan', 'list': [3, 5, 4, 'w']}
# [3, 5]

# %%
def findmax(x,y):
    if x<y:
        return y 
    return x

# %%
print(findmax(7,3))
# Out:
# 7
